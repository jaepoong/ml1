# %%
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import re,unicodedata

# %%
#크롬 드라이버 사용
driver = webdriver.Chrome(r'/Users/seoljaejung/Desktop/sbd/chromedriver')
url = 'https://www.instagram.com'
driver.get(url)#인스타그램 열기
time.sleep(3)
#로그인.아이디
email = 'tjfwownd@naver.com'
input_id = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[0]
input_id.clear()
input_id.send_keys(email)
#로그인.비번
password = 'die8246wnd!'
input_pw = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[1]
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()

time.sleep(3)
#해쉬태그로 접속
def insta_search(word):
    url = 'https://www.instagram.com/explore/tags/' + word
    return url
word=input('검색할 키워드를 입력하십셔: ')
url = insta_search(word)
driver.get(url)
time.sleep(3)

html=driver.page_source
soup=BeautifulSoup(html)

insta=soup.select('.v1Nh3.kIKUG._bz0w')

#스크롤링
n=1
scroll=int(input("스크롤 횟수 입력: "))
height=driver.execute_script("return document.body.scrollHeight") # 현재 화면 스크롤 높이
for i in range(scroll):
    for i in range(3):
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        new_height=driver.execute_script("return document.body.scrollHeight") # 갱신된 스크롤 높이
        if new_height==height:
            break
        else:
            height=new_height

    for i in insta:
        print('https://www.instagram.com'+i.a['href'])
        imgUrl=i.select_one('.KL4Bh').img['src']
        f=urlopen(imgUrl)
        h=open('./img/'+word+str(n)+'.jpg','wb')
        img=f.read()
        h.write(img)
        #with urlopen(imgUrl) as f:
         #   with open('./img/'+word+str(n)+'.jpg','wb') as h:
          #      img=f.read()
           #     h.write(img)
        n=n+1
        print(imgUrl)
        print()
    sleep(3)
# Out:
# 검색할 키워드를 입력하십셔: 간판
# 스크롤 횟수 입력: 3
# https://www.instagram.com/p/COwqT12BMYV/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c180.0.1079.1079a/s640x640/184024519_321293419563841_6791285918147251828_n.jpg?tp=1&_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=-PlCIFGVt_QAX-kVJd4&edm=ABZsPhsBAAAA&ccb=7-4&oh=7902cc4f11688b6c0d326df0e20d5ac7&oe=60C37BC3&_nc_sid=4efc9f
#
# https://www.instagram.com/p/CObzYVnn0Tf/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/181605422_2964285877193437_5244645655499992570_n.jpg?tp=1&_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=K54bRto_g9gAX8zQHH9&edm=ABZsPhsBAAAA&ccb=7-4&oh=d89b5f5aa5eb0bdd427dcce37015a47c&oe=60C0F138&_nc_sid=4efc9f
#
# https://www.instagram.com/p/COPhisYDN5Q/
# ...
