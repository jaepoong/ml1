# %%
# %cd /content/drive/MyDrive/데이터사이언스/학습
# !pwd
# Out:
# /content/drive/MyDrive/데이터사이언스/학습
# /content/drive/MyDrive/데이터사이언스/학습

# %%
# !git init .
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/데이터사이언스/학습/.git/

# %%
# !git config --global user.email "tjfwownd@naver.com"
# !git config --global user.name "jaepoong"

# %%
# !git add -A
# !git commit -am "forth"
# Out:
# error: open("논문/2.gdoc"): Operation not supported
# error: unable to index file 논문/2.gdoc
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
# 	"PIL\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274.ipynb"
# 	YOLOv4_Tutorial.ipynb
# 	"do it \341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274.ipynb"
# 	git.ipynb
# 	instagram crawling.ipynb
# 	pyautogui.ipynb
# 	"\341\204\202\341\205\251\341\206\253\341\204\206\341\205\256\341\206\253/"
# 	"\341\204\213\341\205\265\341\204\200\341\205\245\341\206\272\341\204\213\341\205\265 \341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245\341\204\207\341\205\256\341\206\253\341\204\211\341\205\245\341\206\250\341\204\213\341\205\265\341\204\203\341\205\241/"
#
# nothing added to commit but untracked files present

# %%
# !git remote add origin https://jaepoong:die8246wnd@github.com/jaepoong/ml1.git
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push --set-upstream origin master
# Out:
# Counting objects: 37, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (37/37), done.
# Writing objects: 100% (37/37), 41.51 MiB | 9.58 MiB/s, done.
# Total 37 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/jaepoong/ml1.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git push -f origin master
# Out:
# Everything up-to-date
